# %% [markdown]
# <a href="https://colab.research.google.com/github/surajsarkar3526-cyber/JavaLearning/blob/master/Pandas_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]
runs_ser = pd.Series(runs)
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks, index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Nitish ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='Nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'Nitish ke marks'

# %%
# is_unique
marks_series.is_unique
# Out:
# True

# %%
pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
# with one col
subs = pd.read_csv('/content/subs.csv').iloc[:, 0]
subs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/388560157.py in <cell line: 0>()
#       1 # with one col
# ----> 2 subs = pd.read_csv('/content/subs.csv').iloc[:, 0]
#       3 subs
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/subs.csv'

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').iloc[:,0]
vk
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/3225180566.py in <cell line: 0>()
#       1 # with 2 cols
# ----> 2 vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').iloc[:,0]
#       3 vk
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/kohli_ipl.csv'

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').iloc[:,0]
movies
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_479/1365920109.py in <cell line: 0>()
# ----> 1 movies = pd.read_csv('/content/bollywood.csv',index_col='movie').iloc[:,0]
#       2 movies
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/bollywood.csv'

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1362567757.py in <cell line: 0>()
#       1 # head and tail
# ----> 2 subs.head()
#
# NameError: name 'subs' is not defined

# %%
vk.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1886070616.py in <cell line: 0>()
# ----> 1 vk.head(3)
#
# NameError: name 'vk' is not defined

# %%
vk.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2923732703.py in <cell line: 0>()
# ----> 1 vk.tail(10)
#
# NameError: name 'vk' is not defined

# %%
# sample
movies.sample(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/4084364094.py in <cell line: 0>()
#       1 # sample
# ----> 2 movies.sample(5)
#
# NameError: name 'movies' is not defined

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3313091203.py in <cell line: 0>()
#       1 # value_counts -> movies
# ----> 2 movies.value_counts()
#
# NameError: name 'movies' is not defined

# %%
# sort_values -> inplace
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2256978144.py in <cell line: 0>()
#       1 # sort_values -> inplace
# ----> 2 vk.sort_values(ascending=False).head(1).values[0]
#
# NameError: name 'vk' is not defined

# %%
vk.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/910477176.py in <cell line: 0>()
# ----> 1 vk.sort_values(ascending=False)
#
# NameError: name 'vk' is not defined

# %%
# sort_index -> inplace -> movies

# %%
Vk = vk.sort_values()
Vk
Vk.sort_values(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3757657504.py in <cell line: 0>()
# ----> 1 Vk = vk.sort_values()
#       2 Vk
#       3 Vk.sort_values(inplace=True)
#
# NameError: name 'vk' is not defined

# %%
# sort_index -> inplace -> movies
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/639826876.py in <cell line: 0>()
#       1 # sort_index -> inplace -> movies
# ----> 2 movies
#
# NameError: name 'movies' is not defined

# %%
movies.sort_index(ascending=False,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/641681255.py in <cell line: 0>()
# ----> 1 movies.sort_index(ascending=False,inplace=True)
#
# NameError: name 'movies' is not defined

# %%
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/878749064.py in <cell line: 0>()
# ----> 1 movies
#
# NameError: name 'movies' is not defined

# %% [markdown]
# ### Series Maths Methods

# %%
# count
vk.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1283533263.py in <cell line: 0>()
#       1 # count
# ----> 2 vk.count()
#
# NameError: name 'vk' is not defined

# %%
movies.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1767306899.py in <cell line: 0>()
# ----> 1 movies.count()
#
# NameError: name 'movies' is not defined

# %%
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/878749064.py in <cell line: 0>()
# ----> 1 movies
#
# NameError: name 'movies' is not defined

# %%
# sum - > product
subs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1829115504.py in <cell line: 0>()
#       1 # sum - > product
# ----> 2 subs
#
# NameError: name 'subs' is not defined

# %%
subs.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/278961069.py in <cell line: 0>()
# ----> 1 subs.sum()
#
# NameError: name 'subs' is not defined

# %%
subs.product()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/371150473.py in <cell line: 0>()
# ----> 1 subs.product()
#
# NameError: name 'subs' is not defined

# %%
# mean - > median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3652312320.py in <cell line: 0>()
#       1 # mean - > median -> mode -> std -> var
# ----> 2 subs.mean()
#       3 print(vk.median())
#       4 print(movies.mode())
#       5 print(subs.std())
#
# NameError: name 'subs' is not defined

# %%
# min/max
subs.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2118991576.py in <cell line: 0>()
#       1 # min/max
# ----> 2 subs.min()
#
# NameError: name 'subs' is not defined

# %%
subs.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/125948560.py in <cell line: 0>()
# ----> 1 subs.max()
#
# NameError: name 'subs' is not defined

# %%
# describe
vk.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1357251034.py in <cell line: 0>()
#       1 # describe
# ----> 2 vk.describe()
#
# NameError: name 'vk' is not defined

# %%
subs.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1169471872.py in <cell line: 0>()
# ----> 1 subs.describe()
#
# NameError: name 'subs' is not defined

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x[0]
# Out:
# np.int64(12)

# %%
# negative indexing
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_479/3683148033.py in <cell line: 0>()
#       1 # negative indexing
# ----> 2 x[-1]
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     413                 return self._range.index(new_key)
#     414             except ValueError as err:
# --> 415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
#     417             raise KeyError(key)
#
# KeyError: -1

# %%
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/878749064.py in <cell line: 0>()
# ----> 1 movies
#
# NameError: name 'movies' is not defined

# %%
movies[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3901301928.py in <cell line: 0>()
# ----> 1 movies[0]
#
# NameError: name 'movies' is not defined

# %%
movies['Zor Lagaa Ke...Haiya!']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2172956343.py in <cell line: 0>()
# ----> 1 movies['Zor Lagaa Ke...Haiya!']
#
# NameError: name 'movies' is not defined

# %%
movies[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2731571422.py in <cell line: 0>()
# ----> 1 movies[-1]
#
# NameError: name 'movies' is not defined

# %%
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# Name: Nitish ke marks, dtype: int64

# %%
marks_series[-1]

# %%
# slicing
vk[5:17]

# %%
# negative slicing
vk[-5:]

# %%
movies[-5:]

# %%
movies[::2]

# %%
# fancy indexing
vk[[1,3,4,5]]

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks_series

# %%
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipykernel_479/3660931059.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %%
# what if an index does not exist
marks_series['sst'] = 90
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst         90
# Name: Nitish ke marks, dtype: int64

# %%
# slicing
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
# fancy indexing
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
# using index label
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/833762835.py in <cell line: 0>()
#       1 # using index label
# ----> 2 movies
#
# NameError: name 'movies' is not defined

# %%
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))

# %%
# type conversion
list(marks_series)

# %%
dict(subs)

# %%
dict(marks_series)

# %%
# membership operator
'2 States (2014 film)' in movies

# %%
'Alia Bhatt' in movies.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1105670589.py in <cell line: 0>()
# ----> 1 'Alia Bhatt' in movies.values
#
# NameError: name 'movies' is not defined

# %%
movies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/878749064.py in <cell line: 0>()
# ----> 1 movies
#
# NameError: name 'movies' is not defined

# %%
# looping
for i in movies.index:
  print(i)

# %%
# Arithematic operator
100 - marks_series

# %%
# Relational operator

vk >= 50

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# find the no of 50's and 100's scored by kohli
vk >= 50

# %%
vk[vk >= 50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1954570606.py in <cell line: 0>()
# ----> 1 vk[vk >= 50]
#
# NameError: name 'vk' is not defined

# %%
vk[vk >= 50].size

# %%
# find number of ducks
vk[vk == 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3553718259.py in <cell line: 0>()
#       1 # find number of ducks
# ----> 2 vk[vk == 0]
#
# NameError: name 'vk' is not defined

# %%
vk[vk==0].size

# %%
# Count number of day when I had more than 200 subs a day
subs

# %%
subs[subs > 200]

# %%
subs[subs > 200].size

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()

# %%
movies.value_counts().head(20).plot(kind='bar')

# %%
movies.value_counts().head(20).plot(kind='pie')

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/1274534555.py in <cell line: 0>()
#       1 # astype
#       2 import sys
# ----> 3 sys.getsizeof(vk)
#
# NameError: name 'vk' is not defined

# %%
sys.getsizeof(vk.astype('int16'))

# %%
# between
vk[vk.between(51,99)].size

# %%
subs

# %%
subs.clip(100,200)

# %%
# drop duplicate
temp = pd.series([1,1,2,2,3,3,4,4])
temp

# %%
temp.drop_duplicates(keep='last')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3970371115.py in <cell line: 0>()
# ----> 1 temp.drop_duplicates(keep='last')
#
# NameError: name 'temp' is not defined

# %%
temp.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/2429716513.py in <cell line: 0>()
# ----> 1 temp.duplicated().sum()
#
# NameError: name 'temp' is not defined

# %%
vk.duplicated().sum()

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp

# %%
temp.size

# %%
temp.count()

# %%
# isnull
temp.isnull().sum()

# %%
# dropna
temp.dropna()

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/394216418.py in <cell line: 0>()
#       1 # fillna
# ----> 2 temp.fillna(temp.mean())
#
# NameError: name 'temp' is not defined

# %%
# isin
vk[(vk == 49) | (vk == 99)]

# %%
vk[vk.isin([49,99])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_479/3424228104.py in <cell line: 0>()
# ----> 1 vk[vk.isin([49,99])]
#
# NameError: name 'vk' is not defined

# %%
# apply
movies

# %%
movies.apply(lambda x:x.split()[0].upper())

# %%
subs

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')

# %%
subs.mean()

# %%
# copy

# %%
vk

# %%
new = vk.head()

# %%
new

# %%
new[1] = 1

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
new

# %%
vk
